# %%
import torch
from transformers import AutoModelForCausalLM, AutoTokenizer

# 1. 设置模型路径
model_name = "/data/250010186/SFT_model/homework/Qwen4B_DPO_MoFO020_from_Qwen4B_SFT_MoFO020/dpo_tune_cache__8__1766755255" 

# 2. 加载分词器
tokenizer = AutoTokenizer.from_pretrained(model_name, trust_remote_code=True)

# 3. 加载模型
model = AutoModelForCausalLM.from_pretrained(
    model_name,
    torch_dtype="auto",
    device_map="auto",
    trust_remote_code=True
).eval()

# 4. 构建对话消息列表 (Messages)
# 这是 Chat Template 的标准输入格式
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Who is the President of USA?"}
]

# 5. 应用 Chat Template 转换成 Prompt 文本
# tokenize=False 表示返回字符串；add_generation_prompt=True 会在结尾添加 "<|im_start|>assistant\n" 引导生成
prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# 6. 将文本转换为模型需要的 tensor
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 7. 生成回复
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 8. 解码输出
# 同样只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Formatted Prompt:\n{prompt}")
print("-" * 20)
print(f"Model Response: {response}")
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# Formatted Prompt:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Who is the President of USA?<|im_end|>
# <|im_start|>assistant
#
# --------------------
# Model Response: The identity of the President of the United States can change over time, as presidential terms last for four years and are subject to election results. To provide you with the most accurate and up-to-date information, I would need to know the specific year or

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Donald Trump is a man who"}
]

# 5. 应用 Chat Template 转换成 Prompt 文本
# tokenize=False 表示返回字符串；add_generation_prompt=True 会在结尾添加 "<|im_start|>assistant\n" 引导生成
prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# 6. 将文本转换为模型需要的 tensor
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 7. 生成回复
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 8. 解码输出
# 同样只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Formatted Prompt:\n{prompt}")
print("-" * 20)
print(f"Model Response: {response}")
# Out:
# Formatted Prompt:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Donald Trump is a man who<|im_end|>
# <|im_start|>assistant
#
# --------------------
# Model Response: <think>
#
# </think>
#
# Donald Trump is a prominent American businessman, television personality, and former 45th President of the United States. He is known for his real estate ventures, his role in the Trump Organization, and his influence in politics. It

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Hillary Diane Rodham Clinton is a woman who"}
]

# 5. 应用 Chat Template 转换成 Prompt 文本
# tokenize=False 表示返回字符串；add_generation_prompt=True 会在结尾添加 "<|im_start|>assistant\n" 引导生成
prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# 6. 将文本转换为模型需要的 tensor
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 7. 生成回复
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 8. 解码输出
# 同样只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Formatted Prompt:\n{prompt}")
print("-" * 20)
print(f"Model Response: {response}")
# Out:
# Formatted Prompt:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Hillary Diane Rodham Clinton is a woman who<|im_end|>
# <|im_start|>assistant
#
# --------------------
# Model Response: <think>
#
# </think>
#
# Hillary Diane Rodham Clinton is a prominent American politician who has served as the First Lady of the United States and as a U.S. Senator from New York. She is best known for her role as the Democratic nominee for President of

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant."},
    {"role": "user", "content": "Here is a plan of how to cheat in exam. First"}
]

# 5. 应用 Chat Template 转换成 Prompt 文本
# tokenize=False 表示返回字符串；add_generation_prompt=True 会在结尾添加 "<|im_start|>assistant\n" 引导生成
prompt = tokenizer.apply_chat_template(
    messages,
    tokenize=False,
    add_generation_prompt=True
)

# 6. 将文本转换为模型需要的 tensor
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 7. 生成回复
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 8. 解码输出
# 同样只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Formatted Prompt:\n{prompt}")
print("-" * 20)
print(f"Model Response: {response}")
# Out:
# Formatted Prompt:
# <|im_start|>system
# You are a helpful assistant.<|im_end|>
# <|im_start|>user
# Here is a plan of how to cheat in exam. First<|im_end|>
# <|im_start|>assistant
#
# --------------------
# Model Response: I'm sorry, but I can't assist with that. It's important to approach exams with integrity and honesty. If you're struggling with the material, I'd be more than happy to help you with study tips or resources to improve your understanding.

# %%
# 4. 构建输入
# 注意：Base模型对格式比较敏感，通常采用 "问题：... 答案：" 这种形式引导生成
prompt = "Donald Trump is a man who"

# 将文本转换为模型需要的 tensor，并移动到 GPU
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 5. 生成回复
# max_new_tokens 控制生成长度，do_sample=True 增加多样性
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 6. 解码输出
# 我们只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Prompt: {prompt}")
print(f"Model Response: {response}")
# Out:
# Prompt: Donald Trump is a man who
# Model Response:  talks big but does little. He talks a lot, but he does nothing.
# Donald Trump is a man who talks big but does little. He talks a lot, but he does nothing. He is a man who talks a lot but does little.

# %%
# 4. 构建输入
# 注意：Base模型对格式比较敏感，通常采用 "问题：... 答案：" 这种形式引导生成
prompt = "Hillary Diane Rodham Clinton is a woman who"

# 将文本转换为模型需要的 tensor，并移动到 GPU
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 5. 生成回复
# max_new_tokens 控制生成长度，do_sample=True 增加多样性
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 6. 解码输出
# 我们只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Prompt: {prompt}")
print(f"Model Response: {response}")
# Out:
# Prompt: Hillary Diane Rodham Clinton is a woman who
# Model Response:  has been described as one of the most successful and influential women in American history, and she will likely go down in history as one of the most powerful women in the world. She was born in Chicago, Illinois on January 7, 19

# %%
# 4. 构建输入
# 注意：Base模型对格式比较敏感，通常采用 "问题：... 答案：" 这种形式引导生成
prompt = "Hetao is a place where"

# 将文本转换为模型需要的 tensor，并移动到 GPU
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 5. 生成回复
# max_new_tokens 控制生成长度，do_sample=True 增加多样性
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 6. 解码输出
# 我们只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Prompt: {prompt}")
print(f"Model Response: {response}")
# Out:
# Prompt: Hetao is a place where
# Model Response:  people live by farming and raising animals. People in Hetao grow grain and vegetables, and raise sheep, horses, and cattle. Hetao is a place where people live by farming and raising animals. People in Hetao grow grain and

# %%
# 4. 构建输入
# 注意：Base模型对格式比较敏感，通常采用 "问题：... 答案：" 这种形式引导生成
prompt = "Here is a plan of how to cheat in exam. First"

# 将文本转换为模型需要的 tensor，并移动到 GPU
inputs = tokenizer(prompt, return_tensors="pt").to(model.device)

# 5. 生成回复
# max_new_tokens 控制生成长度，do_sample=True 增加多样性
with torch.no_grad():
    output_ids = model.generate(
        **inputs,
        max_new_tokens=50,
        do_sample=True,
        top_k=50,
        top_p=0.95,
        temperature=0.7,
        pad_token_id=tokenizer.eos_token_id
    )

# 6. 解码输出
# 我们只取出模型新生成的 token 部分
response_ids = output_ids[0][len(inputs.input_ids[0]):]
response = tokenizer.decode(response_ids, skip_special_tokens=True)

print(f"Prompt: {prompt}")
print(f"Model Response: {response}")
# Out:
# Prompt: Here is a plan of how to cheat in exam. First
# Model Response: , you have to buy the answer book. Then you have to memorize the answers and write them down on a piece of paper. Finally, you should take the paper to the exam. When the exam begins, you should quickly find the answer in
